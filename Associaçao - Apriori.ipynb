# %%
# !pip install efficient_apriori
from efficient_apriori import apriori
import pandas as pd

# %%
df = pd.read_csv("market_2.csv",header=None,delimiter=',')

# %%
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
# Transformando o dataframe em lista de lista, para aplica o algoritmo
compras = []
for i in range(0,len(df)):
    compras.append([str(df.values[i,j]) for j in range(0,20) if str(df.values[i,j])!='nan'])

# %%
compras
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers', 'meatballs', 'eggs'],
#  ['chutney'],
#  ['turkey', 'avocado'],
#  ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'],
#  ['low fat yogurt'],
#  ['whole wheat pasta', 'french fries'],
#  ['soup', 'light cream', 'shallot'],
#  ['frozen vegetables', 'spaghetti', 'green tea'],
#  ['french fries'],
#  ['eggs', 'pet food'],
#  ['cookies'],
#  ['turkey', 'burgers', 'mineral water', 'eggs', 'cooking oil'],
#  ['spaghetti', 'champagne', 'cookies'],
#  ['mineral water', 'salmon'],
#  ['mineral water'],
#  ['shrimp',
#   'chocolate',
#   'chicken',
#   'honey',
#   'oil',
#   'cooking oil',
# ...

# %%
# Gerando as regras e cestas com corte minimo de support e confidence
itemsets,rules = apriori(compras,min_support=0.001,min_confidence=0.35)

# %%
# Mostrando todas as regras geradas
for x in rules:
    print(x)
# Out:
# {almonds} -> {mineral water} (conf: 0.373, supp: 0.008, lift: 1.563, conv: 1.214)
# {green grapes} -> {mineral water} (conf: 0.353, supp: 0.003, lift: 1.481, conv: 1.177)
# {olive oil} -> {mineral water} (conf: 0.419, supp: 0.028, lift: 1.758, conv: 1.311)
# {salmon} -> {mineral water} (conf: 0.401, supp: 0.017, lift: 1.683, conv: 1.272)
# {spinach} -> {mineral water} (conf: 0.377, supp: 0.003, lift: 1.583, conv: 1.223)
# {whole weat flour} -> {mineral water} (conf: 0.371, supp: 0.003, lift: 1.558, conv: 1.212)
# {milk} -> {mineral water} (conf: 0.370, supp: 0.048, lift: 1.554, conv: 1.210)
# {cooking oil} -> {mineral water} (conf: 0.394, supp: 0.020, lift: 1.654, conv: 1.257)
# {black tea} -> {mineral water} (conf: 0.374, supp: 0.005, lift: 1.568, conv: 1.216)
# {chicken} -> {mineral water} (conf: 0.380, supp: 0.023, lift: 1.594, conv: 1.228)
# {extra dark chocolate} -> {mineral water} (conf: 0.478, supp: 0.006, lift: 2.004, conv: 1.458)
# ...

# %%
# Filtrando regras que possuem, pelo menos, 2 item a esquerda e 1 a direita
rules_rhs = filter(lambda rule: len(rule.lhs) > 1 and len(rule.rhs) > 0, rules)
for rule in sorted(rules_rhs, key=lambda rule: rule.confidence, reverse = True): # Ordenando as regras do maior para menor confidence
  print(rule)
# Out:
# {ground beef, light cream, olive oil} -> {mineral water} (conf: 1.000, supp: 0.001, lift: 4.195, conv: 761631782.429)
# {cake, olive oil, shrimp} -> {mineral water} (conf: 1.000, supp: 0.001, lift: 4.195, conv: 761631782.429)
# {cake, meatballs, mineral water} -> {milk} (conf: 1.000, supp: 0.001, lift: 7.717, conv: 870417277.696)
# {french fries, mushroom cream sauce, pasta} -> {escalope} (conf: 1.000, supp: 0.001, lift: 12.607, conv: 920677243.034)
# {mushroom cream sauce, pasta} -> {escalope} (conf: 0.950, supp: 0.003, lift: 11.976, conv: 18.414)
# {red wine, soup} -> {mineral water} (conf: 0.933, supp: 0.002, lift: 3.916, conv: 11.424)
# {eggs, mineral water, pasta} -> {shrimp} (conf: 0.909, supp: 0.001, lift: 12.722, conv: 10.214)
# {herb & pepper, mineral water, rice} -> {ground beef} (conf: 0.909, supp: 0.001, lift: 9.252, conv: 9.919)
# {ground beef, pancakes, whole wheat rice} -> {mineral water} (conf: 0.909, supp: 0.001, lift: 3.814, conv: 8.378)
# ...

# %%
itemsets,rules = apriori(compras,min_support = 0.01,min_confidence = 0.05)

# %%
rules_rhs = filter(lambda rule: len(rule.lhs) > 0 and len(rule.rhs) > 0, rules)
for rule in sorted(rules_rhs, key=lambda rule: rule.confidence, reverse = True):
  if 'soup' in rule.rhs or 'soup' in rule.lhs : #filtrando regras que possuem "soup" entre os itens
        print(rule)
# Out:
# {soup} -> {mineral water} (conf: 0.456, supp: 0.023, lift: 1.915, conv: 1.401)
# {soup} -> {milk} (conf: 0.301, supp: 0.015, lift: 2.321, conv: 1.245)
# {soup} -> {spaghetti} (conf: 0.282, supp: 0.014, lift: 1.622, conv: 1.151)
# {soup} -> {chocolate} (conf: 0.201, supp: 0.010, lift: 1.224, conv: 1.046)
# {milk} -> {soup} (conf: 0.117, supp: 0.015, lift: 2.321, conv: 1.076)
# {mineral water} -> {soup} (conf: 0.097, supp: 0.023, lift: 1.915, conv: 1.051)
# {spaghetti} -> {soup} (conf: 0.082, supp: 0.014, lift: 1.622, conv: 1.034)
# {chocolate} -> {soup} (conf: 0.062, supp: 0.010, lift: 1.224, conv: 1.012)
